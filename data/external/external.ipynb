# %% [markdown]
# # External Data
#
# This project does not use any third-party or external datasets.
# All analysis and modeling are performed using the employee
# performance dataset provided by IABAC for the INX Future Inc project.
