# %% [markdown]
# # References
#
# 1. INX Future Inc Employee Performance Dataset
#    Source: IABAC Project Dataset
#    Description: Employee-level dataset containing demographic, work,
#    compensation, satisfaction, and performance rating information.
#
# 2. Scikit-learn Documentation
#    URL: https://scikit-learn.org/stable/
#    Usage: Used for data preprocessing, model training, and evaluation
#    including Label Encoding, Train-Test Split, and Random Forest Classifier.
#
# 3. Pandas Documentation
#    URL: https://pandas.pydata.org/
#    Usage: Used for data loading, data manipulation, and preprocessing.
#
# 4. NumPy Documentation
#    URL: https://numpy.org/
#    Usage: Used for numerical operations and array handling.
#
# 5. Matplotlib Documentation
#    URL: https://matplotlib.org/
#    Usage: Used for data visualization and plotting.
#
# 6. Seaborn Documentation
#    URL: https://seaborn.pydata.org/
#    Usage: Used for exploratory data analysis and visualization.
