# %% [markdown]
# # INX Future Inc – Employee Performance Analysis
#
# **Project Code:** 10281
# **Organization:** INX Future Inc
# **Domain:** Human Resource Analytics / Data Science
#
# ---
#
# ## 📌 Project Overview
#
# INX Future Inc is a global data analytics and automation solutions provider.
# Recently, the organization observed a decline in employee performance indexes, resulting in an 8% reduction in client satisfaction.
#
# This project analyzes employee data to:
# - Identify department-wise performance trends
# - Discover key factors influencing employee performance
# - Build a predictive machine learning model
# - Provide actionable recommendations to improve performance without affecting employee morale
#
# ---
#
# ## 🎯 Business Objectives
#
# 1. Analyze **department-wise employee performance**
# 2. Identify **top 3 factors impacting performance**
# 3. Build a **predictive model** for employee performance
# 4. Provide **data-driven recommendations** for management
#
# ---
#
# ## 📂 Project Directory Structure

# %% [markdown]
# ```INX_Employee_Performance_Project_IABAC
# │
# ├── data
# │   ├── raw
# │   │   └── INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls
# │   ├── processed
# │   │   └── employee_performance_processed.csv
# │   └── external
# │       └── external_data_details.ipynb
# │
# ├── models
# │   └── employee_performance_model.pkl
# │
# ├── Project Summary
# │   ├── Requirement
# │   │   └── project_requirement.ipynb
# │   ├── Analysis
# │   │   └── analysis_summary.ipynb
# │   └── Summary
# │       └── final_recommendations.ipynb
# │
# ├── references
# │   └── data_dictionary.ipynb
# │
# ├── src
# │   ├── Data Processing
# │   │   ├── data_processing.ipynb
# │   │   └── data_exploratory_analysis.ipynb
# │   │
# │   ├── models
# │   │   └── train_model.ipynb
# │   │
# │   └── visualization
# │       └── visualize.ipynb
# │
# └── README.ipynb

# %% [markdown]
# ---
#
# ## 🧠 Project Workflow
#
# 1. **Data Collection**
#    - Raw dataset stored in `data/raw`
#
# 2. **Data Preprocessing**
#    - Cleaning, encoding, and transformation
#    - Output stored in `data/processed`
#
# 3. **Exploratory Data Analysis**
#    - Department-wise performance
#    - Correlation analysis
#
# 4. **Feature Engineering & Selection**
#    - Identified key performance drivers
#
# 5. **Model Training**
#    - Random Forest Classifier
#    - Model saved in `models/employee_performance_model.pkl`
#
# 6. **Visualization**
#    - Feature importance and performance insights
#
# 7. **Business Recommendations**
#    - Provided in `Project Summary/Summary`
#
# ---
#
# ## 🤖 Machine Learning Model
#
# - **Algorithm:** Random Forest Classifier
# - **Reason:** Handles feature interactions, robust to noise, high accuracy
# - **Evaluation Metric:** Accuracy, Precision, Recall, F1-score
#
# ---
#
# ## 📊 Key Insights
#
# - Job Satisfaction, Monthly Income, and Work-Life Balance are top performance drivers
# - Mid-level experience employees show the highest performance
# - Department-wise interventions are required for consistent productivity
#
# ---
#
# ## ✅ Conclusion
#
# This project delivers actionable insights and a reliable predictive model that enables INX Future Inc to take data-driven HR decisions while maintaining employee morale and employer brand value.
#
# ---
#
# **Prepared for:** IABAC™ Certified Data Scientist Project Submission

# %% [markdown]
# ---
#
# ### 📌 Folder Description
#
# - **data/raw** – Original dataset provided by IABAC (immutable)
# - **data/processed** – Cleaned and encoded dataset used for modeling
# - **models** – Trained machine learning model
# - **Project Summary** – Business understanding, analysis, and recommendations
# - **references** – Data dictionary and explanatory materials
# - **src** – Source code notebooks for processing, modeling, and visualization
# - **README.ipynb** – Entry point explaining the complete project
