# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Objective
# To understand patterns, trends, and relationships between employee attributes and performance ratings.

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Objective
# To understand patterns, trends, and relationships between employee attributes and performance ratings.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='EmpDepartment', y='PerformanceRating', data=df)
plt.xticks(rotation=45)
plt.title('Department-wise Performance Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Key Observations
#
# - R&D and Sales departments show higher variability in performance.
# - Employees with higher job satisfaction and better work-life balance tend to perform better.

# %% [markdown]
# # Feature Selection and Engineering
#
# ## Important Features Identified
# 1. JobSatisfaction – Strong positive correlation with performance
# 2. MonthlyIncome – Higher income correlates with higher performance
# 3. YearsAtCompany – Experience improves performance up to a certain level

# %%
corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 corr = df.corr()
#       2 plt.figure(figsize=(12,8))
#       3 sns.heatmap(corr, cmap='coolwarm')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv('../../data/processed/employee_performance_processed.csv')

print(df.columns.tolist())
# Out:
# ['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency', 'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction', 'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime', 'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction', 'TotalWorkExperienceInYears', 'TrainingTimesLastYear', 'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany', 'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'PerformanceRating']
